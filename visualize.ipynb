# %%
import pandas as pd

# %%
data = pd.read_csv('./assets/weather_data.csv')

# %%
data
# Out:
#           name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0        Delhi  01-11-2022     32.0     18.1  24.6          31.7
# 1        Delhi  02-11-2022     30.1     18.5  24.0          30.4
# 2        Delhi  03-11-2022     31.0     17.8  23.9          30.7
# 3        Delhi  04-11-2022     31.0     19.1  24.4          31.5
# 4        Delhi  05-11-2022     29.7     19.0  24.0          32.0
# ..         ...         ...      ...      ...   ...           ...
# 950  Prayagraj  06-05-2023     39.3     28.6  34.3          37.4
# 951  Prayagraj  07-05-2023     41.7     30.1  36.1          39.0
# 952  Prayagraj  08-05-2023     42.5     30.3  36.9          40.0
# 953  Prayagraj  09-05-2023     43.1     31.0  37.3          39.8
# 954  Prayagraj  10-05-2023     42.5     30.2  36.7          38.2
#
#      feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0            18.1       24.5  15.9      62.6  ...         15.8        7
# ...

# %%
data['name'].unique()
# Out:
# array(['Delhi', 'London', 'Jodhpur', 'Mumbai', 'Prayagraj'], dtype=object)

# %%
data_delhi = data[data['name'] == 'Delhi']
data_london = data[data['name'] == 'London']
data_prayagraj = data[data['name'] == 'Prayagraj']
data_mumbai = data[data['name'] == 'Mumbai']
data_kolkata = data[data['name'] == 'Jodhpur']

# %%
data.icon.unique()
# Out:
# array(['clear-day', 'partly-cloudy-day', 'rain', 'fog', 'cloudy', 'snow'],
#       dtype=object)

# %%
data_delhi
# Out:
#       name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0    Delhi  01-11-2022     32.0     18.1  24.6          31.7          18.1
# 1    Delhi  02-11-2022     30.1     18.5  24.0          30.4          18.5
# 2    Delhi  03-11-2022     31.0     17.8  23.9          30.7          17.8
# 3    Delhi  04-11-2022     31.0     19.1  24.4          31.5          19.1
# 4    Delhi  05-11-2022     29.7     19.0  24.0          32.0          19.0
# ..     ...         ...      ...      ...   ...           ...           ...
# 186  Delhi  06-05-2023     38.5     25.3  31.7          36.5          25.3
# 187  Delhi  07-05-2023     38.8     26.1  30.2          36.8          26.1
# 188  Delhi  08-05-2023     38.5     24.0  31.7          35.8          24.0
# 189  Delhi  09-05-2023     38.6     28.5  33.7          35.4          27.1
# 190  Delhi  10-05-2023     40.2     28.8  34.7          36.7          27.2
#
# ...

# %%
data_delhi.iloc[1]
# Out:
# name                                                            Delhi
# datetime                                                   02-11-2022
# tempmax                                                          30.1
# tempmin                                                          18.5
# temp                                                             24.0
# feelslikemax                                                     30.4
# feelslikemin                                                     18.5
# feelslike                                                        24.0
# dew                                                              16.3
# humidity                                                         64.6
# precip                                                            0.0
# precipprob                                                        0.0
# precipcover                                                       0.0
# ...
